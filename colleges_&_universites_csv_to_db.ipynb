# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import requests
import time
import json
import csv

# %%
#import csv

df = pd.read_csv("raw/Colleges_and_Universities.csv")
df
#data cleaning with street matching api format needed pull lat long 
#drog unnecessary address
# Out:
#                X              Y  OBJECTID                       ADDRESS  \
# 0   2.097579e+06  741713.299902         1      2101 Hillsborough Street
# 1   2.092281e+06  744629.599844         2      3800 Hillsborough Street
# 2   2.095116e+06  736981.100049         3          1007 Capability Road
# 3   2.107643e+06  735692.700066         4              118 South Street
# 4   2.112693e+06  741014.500118         5           1315 Oakwood Avenue
# 5   2.144425e+06  812169.599934         6         219 S. Wingate Street
# 6   2.087623e+06  692108.900095         7        9101 Fayetteville Road
# 7   2.107440e+06  742210.100089         8            15 E. Peace Street
# 8   2.134938e+06  770863.000133         9            6600 Louisburg Rd
# 9   2.060739e+06  711927.599959        10         3434 Kildaire Farm Rd
# 10  2.122848e+06  740698.100161        11               2901 Holston Ln
# 11  2.049020e+06  766080.999854        12          10908 Chapel Hill Rd
# 12  2.104581e+06  722558.999956        13              321 Chapanoke Rd
# 13  2.105868e+06  729089.000019        14  2200 South Wilmington Street
# 14  2.055586e+06  758889.400064        15       808 Aviation Pkwy #1100
# 15  2.105852e+06  739116.799846        16           225 Hillsborough St
# 16  2.114660e+06  755005.982634        17                  3200 Bush St
# 17  2.205384e+06  757267.557179        18           519 N Industrial Dr
#
#            CITY                                        COLLEGENAME
# 0       Raleigh                  NC State University - Main Campus
# 1       Raleigh                                   Meredith College
# 2       Raleigh                             NCSU Centennial Campus
# 3       Raleigh                                    Shaw University
# 4       Raleigh                              St. Augustine College
# 5   Wake Forest                      Southeastern Baptist Seminary
# 6   Wake County        Wake Technical College Southern Wake Campus
# 7       Raleigh                           William Peace University
# 8       Raleigh        Wake Technical College Northern Wake Campus
# 9          Cary         Wake Technical College Western Wake Campus
# 10      Raleigh  Wake Technical College Perry Health Sciences C...
# 11  Morrisville                  Wake Technical College RTP Campus
# 12      Raleigh  Wake Technical College Public Safety Education...
# 13      Raleigh           Vernon Malone College and Career Academy
# 14  Morrisville                           Campbell University ext.
# 15      Raleigh                     Campbell University Law School
# 16      Raleigh   Wake Technical College Beltline Education Center
# 17      Zebulon  Wake Technical College Eastern Wake Education ...

# %%
df["State"] = np.nan

# %%
df
# Out:
#                X              Y  OBJECTID                       ADDRESS  \
# 0   2.097579e+06  741713.299902         1      2101 Hillsborough Street
# 1   2.092281e+06  744629.599844         2      3800 Hillsborough Street
# 2   2.095116e+06  736981.100049         3          1007 Capability Road
# 3   2.107643e+06  735692.700066         4              118 South Street
# 4   2.112693e+06  741014.500118         5           1315 Oakwood Avenue
# 5   2.144425e+06  812169.599934         6         219 S. Wingate Street
# 6   2.087623e+06  692108.900095         7        9101 Fayetteville Road
# 7   2.107440e+06  742210.100089         8            15 E. Peace Street
# 8   2.134938e+06  770863.000133         9            6600 Louisburg Rd
# 9   2.060739e+06  711927.599959        10         3434 Kildaire Farm Rd
# 10  2.122848e+06  740698.100161        11               2901 Holston Ln
# 11  2.049020e+06  766080.999854        12          10908 Chapel Hill Rd
# 12  2.104581e+06  722558.999956        13              321 Chapanoke Rd
# 13  2.105868e+06  729089.000019        14  2200 South Wilmington Street
# 14  2.055586e+06  758889.400064        15       808 Aviation Pkwy #1100
# 15  2.105852e+06  739116.799846        16           225 Hillsborough St
# 16  2.114660e+06  755005.982634        17                  3200 Bush St
# 17  2.205384e+06  757267.557179        18           519 N Industrial Dr
#
#            CITY                                        COLLEGENAME  State
# 0       Raleigh                  NC State University - Main Campus    NaN
# 1       Raleigh                                   Meredith College    NaN
# 2       Raleigh                             NCSU Centennial Campus    NaN
# 3       Raleigh                                    Shaw University    NaN
# 4       Raleigh                              St. Augustine College    NaN
# 5   Wake Forest                      Southeastern Baptist Seminary    NaN
# 6   Wake County        Wake Technical College Southern Wake Campus    NaN
# 7       Raleigh                           William Peace University    NaN
# 8       Raleigh        Wake Technical College Northern Wake Campus    NaN
# 9          Cary         Wake Technical College Western Wake Campus    NaN
# 10      Raleigh  Wake Technical College Perry Health Sciences C...    NaN
# 11  Morrisville                  Wake Technical College RTP Campus    NaN
# 12      Raleigh  Wake Technical College Public Safety Education...    NaN
# 13      Raleigh           Vernon Malone College and Career Academy    NaN
# 14  Morrisville                           Campbell University ext.    NaN
# 15      Raleigh                     Campbell University Law School    NaN
# 16      Raleigh   Wake Technical College Beltline Education Center    NaN
# 17      Zebulon  Wake Technical College Eastern Wake Education ...    NaN

# %%
df1 = df.fillna('NC')

# %%
df1
# Out:
#                X              Y  OBJECTID                       ADDRESS  \
# 0   2.097579e+06  741713.299902         1      2101 Hillsborough Street
# 1   2.092281e+06  744629.599844         2      3800 Hillsborough Street
# 2   2.095116e+06  736981.100049         3          1007 Capability Road
# 3   2.107643e+06  735692.700066         4              118 South Street
# 4   2.112693e+06  741014.500118         5           1315 Oakwood Avenue
# 5   2.144425e+06  812169.599934         6         219 S. Wingate Street
# 6   2.087623e+06  692108.900095         7        9101 Fayetteville Road
# 7   2.107440e+06  742210.100089         8            15 E. Peace Street
# 8   2.134938e+06  770863.000133         9            6600 Louisburg Rd
# 9   2.060739e+06  711927.599959        10         3434 Kildaire Farm Rd
# 10  2.122848e+06  740698.100161        11               2901 Holston Ln
# 11  2.049020e+06  766080.999854        12          10908 Chapel Hill Rd
# 12  2.104581e+06  722558.999956        13              321 Chapanoke Rd
# 13  2.105868e+06  729089.000019        14  2200 South Wilmington Street
# 14  2.055586e+06  758889.400064        15       808 Aviation Pkwy #1100
# 15  2.105852e+06  739116.799846        16           225 Hillsborough St
# 16  2.114660e+06  755005.982634        17                  3200 Bush St
# 17  2.205384e+06  757267.557179        18           519 N Industrial Dr
#
#            CITY                                        COLLEGENAME State
# 0       Raleigh                  NC State University - Main Campus    NC
# 1       Raleigh                                   Meredith College    NC
# 2       Raleigh                             NCSU Centennial Campus    NC
# 3       Raleigh                                    Shaw University    NC
# 4       Raleigh                              St. Augustine College    NC
# 5   Wake Forest                      Southeastern Baptist Seminary    NC
# 6   Wake County        Wake Technical College Southern Wake Campus    NC
# 7       Raleigh                           William Peace University    NC
# 8       Raleigh        Wake Technical College Northern Wake Campus    NC
# 9          Cary         Wake Technical College Western Wake Campus    NC
# 10      Raleigh  Wake Technical College Perry Health Sciences C...    NC
# 11  Morrisville                  Wake Technical College RTP Campus    NC
# 12      Raleigh  Wake Technical College Public Safety Education...    NC
# 13      Raleigh           Vernon Malone College and Career Academy    NC
# 14  Morrisville                           Campbell University ext.    NC
# 15      Raleigh                     Campbell University Law School    NC
# 16      Raleigh   Wake Technical College Beltline Education Center    NC
# 17      Zebulon  Wake Technical College Eastern Wake Education ...    NC

# %%
# Import API key
# from api_key import api_key
apiKey = '&key=AIzaSyBiBAswT9_Is4Lf3gvrcsjLimgNjApWj3Q'

#set base query_url
query_url = "https://maps.googleapis.com/maps/api/geocode/json?address="

# %%
lat = []
lng = []
ind = []
#iterate through rows to create json response and attach to base url then append to lat, lng, ind list if not found pass 
for index, row in df1.iterrows():
    try:
        response = requests.get(query_url + row['ADDRESS'] + ', ' + row['CITY'] + ', ' +  row['State'] + apiKey)
        json_response = response.json()
        print(json_response)
        lat.append(json_response['results'][0]['geometry']['location']['lat'])
        lng.append(json_response['results'][0]['geometry']['location']['lng'])
        ind.append(index)
    except:
        pass
# Out:
# {'results': [{'address_components': [{'long_name': '2101', 'short_name': '2101', 'types': ['street_number']}, {'long_name': 'Hillsborough Street', 'short_name': 'Hillsborough St', 'types': ['route']}, {'long_name': 'University Park', 'short_name': 'University Park', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27607', 'short_name': '27607', 'types': ['postal_code']}], 'formatted_address': '2101 Hillsborough St, Raleigh, NC 27607, USA', 'geometry': {'location': {'lat': 35.78639709999999, 'lng': -78.6631364}, 'location_type': 'RANGE_INTERPOLATED', 'viewport': {'northeast': {'lat': 35.78774608029149, 'lng': -78.6617874197085}, 'southwest': {'lat': 35.78504811970849, 'lng': -78.66448538029151}}}, 'place_id': 'EiwyMTAxIEhpbGxzYm9yb3VnaCBTdCwgUmFsZWlnaCwgTkMgMjc2MDcsIFVTQSIbEhkKFAoSCTdHNw6M9ayJEdnprkD8mBjCELUQ', 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '3800', 'short_name': '3800', 'types': ['street_number']}, {'long_name': 'Hillsborough Street', 'short_name': 'Hillsborough St', 'types': ['route']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27607', 'short_name': '27607', 'types': ['postal_code']}, {'long_name': '5237', 'short_name': '5237', 'types': ['postal_code_suffix']}], 'formatted_address': '3800 Hillsborough St, Raleigh, NC 27607, USA', 'geometry': {'location': {'lat': 35.7944904, 'lng': -78.6878971}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7958393802915, 'lng': -78.6865481197085}, 'southwest': {'lat': 35.7931414197085, 'lng': -78.68924608029151}}}, 'place_id': 'ChIJr0pO79D1rIkR0fhLtaTxcwA', 'plus_code': {'compound_code': 'Q8V6+QR Raleigh, North Carolina, United States', 'global_code': '8773Q8V6+QR'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '1007', 'short_name': '1007', 'types': ['street_number']}, {'long_name': 'Capability Drive', 'short_name': 'Capability Dr', 'types': ['route']}, {'long_name': 'Southwest Raleigh', 'short_name': 'Southwest Raleigh', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27606', 'short_name': '27606', 'types': ['postal_code']}], 'formatted_address': '1007 Capability Dr, Raleigh, NC 27606, USA', 'geometry': {'location': {'lat': 35.7706358, 'lng': -78.6815077}, 'location_type': 'RANGE_INTERPOLATED', 'viewport': {'northeast': {'lat': 35.7719847802915, 'lng': -78.68015871970849}, 'southwest': {'lat': 35.7692868197085, 'lng': -78.6828566802915}}}, 'place_id': 'EioxMDA3IENhcGFiaWxpdHkgRHIsIFJhbGVpZ2gsIE5DIDI3NjA2LCBVU0EiGxIZChQKEgmh96WbCvWsiRGDSt4lzPlcixDvBw', 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '118', 'short_name': '118', 'types': ['street_number']}, {'long_name': 'West South Street', 'short_name': 'W South St', 'types': ['route']}, {'long_name': 'Downtown', 'short_name': 'Downtown', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27601', 'short_name': '27601', 'types': ['postal_code']}], 'formatted_address': '118 W South St, Raleigh, NC 27601, USA', 'geometry': {'location': {'lat': 35.7723764, 'lng': -78.6421501}, 'location_type': 'RANGE_INTERPOLATED', 'viewport': {'northeast': {'lat': 35.77372538029149, 'lng': -78.64080111970848}, 'southwest': {'lat': 35.7710274197085, 'lng': -78.6434990802915}}}, 'place_id': 'EiYxMTggVyBTb3V0aCBTdCwgUmFsZWlnaCwgTkMgMjc2MDEsIFVTQSIaEhgKFAoSCTlaK9B2X6yJEajnrsoH8iU2EHY', 'types': ['street_address']}, {'address_components': [{'long_name': '118', 'short_name': '118', 'types': ['street_number']}, {'long_name': 'East South Street', 'short_name': 'E South St', 'types': ['route']}, {'long_name': 'Downtown', 'short_name': 'Downtown', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27601', 'short_name': '27601', 'types': ['postal_code']}], 'formatted_address': '118 E South St, Raleigh, NC 27601, USA', 'geometry': {'location': {'lat': 35.7711349, 'lng': -78.6379832}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7724838802915, 'lng': -78.63663421970848}, 'southwest': {'lat': 35.7697859197085, 'lng': -78.63933218029149}}}, 'place_id': 'ChIJq_0yQ3RfrIkRY077ILJfDJw', 'plus_code': {'compound_code': 'Q9C6+FR Raleigh, North Carolina, United States', 'global_code': '8773Q9C6+FR'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '1315', 'short_name': '1315', 'types': ['street_number']}, {'long_name': 'Oakwood Avenue', 'short_name': 'Oakwood Ave', 'types': ['route']}, {'long_name': 'Downtown', 'short_name': 'Downtown', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27610', 'short_name': '27610', 'types': ['postal_code']}, {'long_name': '2247', 'short_name': '2247', 'types': ['postal_code_suffix']}], 'formatted_address': '1315 Oakwood Ave, Raleigh, NC 27610, USA', 'geometry': {'location': {'lat': 35.7847586, 'lng': -78.6210882}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7861075802915, 'lng': -78.6197392197085}, 'southwest': {'lat': 35.7834096197085, 'lng': -78.62243718029151}}}, 'place_id': 'ChIJT_QFQyJfrIkR54O29y16h4w', 'plus_code': {'compound_code': 'Q9MH+WH Raleigh, North Carolina, United States', 'global_code': '8773Q9MH+WH'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '219', 'short_name': '219', 'types': ['street_number']}, {'long_name': 'South Wingate Street', 'short_name': 'S Wingate St', 'types': ['route']}, {'long_name': 'Wake Forest', 'short_name': 'Wake Forest', 'types': ['locality', 'political']}, {'long_name': 'Wake Forest', 'short_name': 'Wake Forest', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27587', 'short_name': '27587', 'types': ['postal_code']}], 'formatted_address': '219 S Wingate St, Wake Forest, NC 27587, USA', 'geometry': {'location': {'lat': 35.97894, 'lng': -78.5146725}, 'location_type': 'RANGE_INTERPOLATED', 'viewport': {'northeast': {'lat': 35.9802889802915, 'lng': -78.51332351970849}, 'southwest': {'lat': 35.97759101970851, 'lng': -78.51602148029151}}}, 'place_id': 'EiwyMTkgUyBXaW5nYXRlIFN0LCBXYWtlIEZvcmVzdCwgTkMgMjc1ODcsIFVTQSIbEhkKFAoSCds889MtUqyJEVp5kxZpyXBcENsB', 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': 'Wake Technical Community College', 'short_name': 'Wake Technical Community College', 'types': ['establishment', 'point_of_interest']}, {'long_name': '9101', 'short_name': '9101', 'types': ['street_number']}, {'long_name': 'Fayetteville Road', 'short_name': 'Fayetteville Rd', 'types': ['route']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Middle Creek', 'short_name': 'Middle Creek', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27603', 'short_name': '27603', 'types': ['postal_code']}, {'long_name': '5655', 'short_name': '5655', 'types': ['postal_code_suffix']}], 'formatted_address': 'Wake Technical Community College, 9101 Fayetteville Rd, Raleigh, NC 27603, USA', 'geometry': {'location': {'lat': 35.6509893, 'lng': -78.7040095}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.6523382802915, 'lng': -78.7026605197085}, 'southwest': {'lat': 35.6496403197085, 'lng': -78.70535848029151}}}, 'place_id': 'ChIJUw87FNOLrIkRf2xDlBDXs20', 'plus_code': {'compound_code': 'M72W+99 Fuquay-Varina, Middle Creek, NC, United States', 'global_code': '8773M72W+99'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '15', 'short_name': '15', 'types': ['street_number']}, {'long_name': 'East Peace Street', 'short_name': 'E Peace St', 'types': ['route']}, {'long_name': 'Downtown', 'short_name': 'Downtown', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27604', 'short_name': '27604', 'types': ['postal_code']}, {'long_name': '1176', 'short_name': '1176', 'types': ['postal_code_suffix']}], 'formatted_address': '15 E Peace St, Raleigh, NC 27604, USA', 'geometry': {'location': {'lat': 35.789286, 'lng': -78.637452}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.79063498029149, 'lng': -78.63610301970849}, 'southwest': {'lat': 35.78793701970849, 'lng': -78.6388009802915}}}, 'place_id': 'ChIJn7VlzkFfrIkRESQW2Vm4-nQ', 'plus_code': {'compound_code': 'Q9Q7+P2 Raleigh, North Carolina, United States', 'global_code': '8773Q9Q7+P2'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '6600', 'short_name': '6600', 'types': ['street_number']}, {'long_name': 'Louisburg Road', 'short_name': 'Louisburg Rd', 'types': ['route']}, {'long_name': 'Northeast Raleigh', 'short_name': 'Northeast Raleigh', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Neuse', 'short_name': 'Neuse', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27616', 'short_name': '27616', 'types': ['postal_code']}], 'formatted_address': '6600 Louisburg Rd, Raleigh, NC 27616, USA', 'geometry': {'location': {'lat': 35.8668492, 'lng': -78.54174859999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.8681981802915, 'lng': -78.54039961970848}, 'southwest': {'lat': 35.8655002197085, 'lng': -78.5430975802915}}}, 'place_id': 'ChIJUdoj62parIkR4EYsD_pZwmA', 'plus_code': {'compound_code': 'VF85+P8 Raleigh, North Carolina, United States', 'global_code': '8773VF85+P8'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '3434', 'short_name': '3434', 'types': ['street_number']}, {'long_name': 'Kildaire Farm Road', 'short_name': 'Kildaire Farm Rd', 'types': ['route']}, {'long_name': 'Cary', 'short_name': 'Cary', 'types': ['locality', 'political']}, {'long_name': 'White Oak', 'short_name': 'White Oak', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27518', 'short_name': '27518', 'types': ['postal_code']}], 'formatted_address': '3434 Kildaire Farm Rd, Cary, NC 27518, USA', 'geometry': {'bounds': {'northeast': {'lat': 35.7065798, 'lng': -78.7951799}, 'southwest': {'lat': 35.7053742, 'lng': -78.7963996}}, 'location': {'lat': 35.7058891, 'lng': -78.7957413}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7073259802915, 'lng': -78.7944407697085}, 'southwest': {'lat': 35.7046280197085, 'lng': -78.79713873029151}}}, 'place_id': 'ChIJiT0m1gKNrIkR0s8Afgo5eE8', 'types': ['premise']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '2901', 'short_name': '2901', 'types': ['street_number']}, {'long_name': 'Holston Lane', 'short_name': 'Holston Ln', 'types': ['route']}, {'long_name': 'East Raleigh', 'short_name': 'East Raleigh', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27610', 'short_name': '27610', 'types': ['postal_code']}], 'formatted_address': '2901 Holston Ln, Raleigh, NC 27610, USA', 'geometry': {'location': {'lat': 35.7848989, 'lng': -78.5847335}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7862478802915, 'lng': -78.58338451970849}, 'southwest': {'lat': 35.78354991970851, 'lng': -78.58608248029151}}}, 'place_id': 'ChIJ-6tWQL5erIkRPNMrAkEzPRc', 'plus_code': {'compound_code': 'QCM8+X4 Raleigh, North Carolina, United States', 'global_code': '8773QCM8+X4'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '10908', 'short_name': '10908', 'types': ['street_number']}, {'long_name': 'Chapel Hill Road', 'short_name': 'Chapel Hill Rd', 'types': ['route']}, {'long_name': 'Morrisville', 'short_name': 'Morrisville', 'types': ['locality', 'political']}, {'long_name': 'Cedar Fork', 'short_name': 'Cedar Fork', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27560', 'short_name': '27560', 'types': ['postal_code']}, {'long_name': '8852', 'short_name': '8852', 'types': ['postal_code_suffix']}], 'formatted_address': '10908 Chapel Hill Rd, Morrisville, NC 27560, USA', 'geometry': {'location': {'lat': 35.853226, 'lng': -78.84098999999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.8545749802915, 'lng': -78.83964101970848}, 'southwest': {'lat': 35.8518770197085, 'lng': -78.8423389802915}}}, 'place_id': 'ChIJh7eUVCDurIkR3wd9XJs8NpM', 'plus_code': {'compound_code': 'V535+7J Morrisville, Cedar Fork, NC, United States', 'global_code': '8773V535+7J'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '321', 'short_name': '321', 'types': ['street_number']}, {'long_name': 'Chapanoke Road', 'short_name': 'Chapanoke Rd', 'types': ['route']}, {'long_name': 'Southwest Raleigh', 'short_name': 'Southwest Raleigh', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'St. Marys', 'short_name': 'St Marys', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27603', 'short_name': '27603', 'types': ['postal_code']}, {'long_name': '3429', 'short_name': '3429', 'types': ['postal_code_suffix']}], 'formatted_address': '321 Chapanoke Rd, Raleigh, NC 27603, USA', 'geometry': {'location': {'lat': 35.73480199999999, 'lng': -78.647729}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7361509802915, 'lng': -78.64638001970849}, 'southwest': {'lat': 35.7334530197085, 'lng': -78.6490779802915}}}, 'place_id': 'ChIJ13DDj_pfrIkRQ_kB0UUN2NE', 'plus_code': {'compound_code': 'P9M2+WW Raleigh, North Carolina, United States', 'global_code': '8773P9M2+WW'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '2200', 'short_name': '2200', 'types': ['street_number']}, {'long_name': 'South Wilmington Street', 'short_name': 'S Wilmington St', 'types': ['route']}, {'long_name': 'Southwest Raleigh', 'short_name': 'Southwest Raleigh', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Swift Creek', 'short_name': 'Swift Creek', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27603', 'short_name': '27603', 'types': ['postal_code']}, {'long_name': '2542', 'short_name': '2542', 'types': ['postal_code_suffix']}], 'formatted_address': '2200 S Wilmington St, Raleigh, NC 27603, USA', 'geometry': {'bounds': {'northeast': {'lat': 35.7533127, 'lng': -78.6425489}, 'southwest': {'lat': 35.7522477, 'lng': -78.6437072}}, 'location': {'lat': 35.7528333, 'lng': -78.64324260000001}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7541291802915, 'lng': -78.64177906970849}, 'southwest': {'lat': 35.7514312197085, 'lng': -78.6444770302915}}}, 'place_id': 'ChIJFwo2opFfrIkRVj99oLfSZvY', 'types': ['premise']}], 'status': 'OK'}
# {'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account', 'results': [], 'status': 'REQUEST_DENIED'}
# {'results': [{'address_components': [{'long_name': 'Campbell University - Norman Adrian Wiggins School of Law', 'short_name': 'Campbell University - Norman Adrian Wiggins School of Law', 'types': ['premise']}, {'long_name': '225', 'short_name': '225', 'types': ['street_number']}, {'long_name': 'Hillsborough Street', 'short_name': 'Hillsborough St', 'types': ['route']}, {'long_name': 'Downtown', 'short_name': 'Downtown', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27603', 'short_name': '27603', 'types': ['postal_code']}], 'formatted_address': 'Campbell University - Norman Adrian Wiggins School of Law, 225 Hillsborough St, Raleigh, NC 27603, USA', 'geometry': {'bounds': {'northeast': {'lat': 35.7803989, 'lng': -78.642596}, 'southwest': {'lat': 35.7798602, 'lng': -78.6432775}}, 'location': {'lat': 35.7801315, 'lng': -78.64296499999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.7814785302915, 'lng': -78.64158776970851}, 'southwest': {'lat': 35.7787805697085, 'lng': -78.64428573029151}}}, 'place_id': 'ChIJ8VJGsm9frIkRdVUKPZu5Yco', 'types': ['premise']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '3200', 'short_name': '3200', 'types': ['street_number']}, {'long_name': 'Bush Street', 'short_name': 'Bush St', 'types': ['route']}, {'long_name': 'North Hills', 'short_name': 'North Hills', 'types': ['neighborhood', 'political']}, {'long_name': 'Raleigh', 'short_name': 'Raleigh', 'types': ['locality', 'political']}, {'long_name': 'St. Matthews', 'short_name': 'St Matthews', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27609', 'short_name': '27609', 'types': ['postal_code']}, {'long_name': '7503', 'short_name': '7503', 'types': ['postal_code_suffix']}], 'formatted_address': '3200 Bush St, Raleigh, NC 27609, USA', 'geometry': {'location': {'lat': 35.8239631, 'lng': -78.6133579}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.8253120802915, 'lng': -78.61200891970849}, 'southwest': {'lat': 35.8226141197085, 'lng': -78.6147068802915}}}, 'place_id': 'ChIJr1tBM99YrIkR8-UKwFv8iz4', 'plus_code': {'compound_code': 'R9FP+HM Raleigh, North Carolina, United States', 'global_code': '8773R9FP+HM'}, 'types': ['street_address']}], 'status': 'OK'}
# {'results': [{'address_components': [{'long_name': '519', 'short_name': '519', 'types': ['street_number']}, {'long_name': 'Industrial Drive', 'short_name': 'Industrial Dr', 'types': ['route']}, {'long_name': 'Zebulon', 'short_name': 'Zebulon', 'types': ['locality', 'political']}, {'long_name': 'Little River', 'short_name': 'Little River', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Wake County', 'short_name': 'Wake County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'North Carolina', 'short_name': 'NC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '27597', 'short_name': '27597', 'types': ['postal_code']}], 'formatted_address': '519 Industrial Dr, Zebulon, NC 27597, USA', 'geometry': {'bounds': {'northeast': {'lat': 35.8288579, 'lng': -78.30691519999999}, 'southwest': {'lat': 35.8286136, 'lng': -78.3073672}}, 'location': {'lat': 35.8287162, 'lng': -78.30718040000001}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 35.83008473029149, 'lng': -78.3057922197085}, 'southwest': {'lat': 35.8273867697085, 'lng': -78.30849018029151}}}, 'place_id': 'ChIJBxXvBptHrIkRHKeQ9xjreIc', 'types': ['premise']}], 'status': 'OK'}

# %%
#move lists to a series
lat = pd.Series(lat)
lng = pd.Series(lng)
ind = pd.Series(ind)

#combine the series together and rename the columns
lat_lng_df = pd.concat([lat, lng, ind],axis=1)
lat_lng_df.columns=['LAT','LNG','IND']
lat_lng_df.head(18)
# Out:
#           LAT        LNG  IND
# 0   35.786397 -78.663136    0
# 1   35.794490 -78.687897    1
# 2   35.770636 -78.681508    2
# 3   35.772376 -78.642150    3
# 4   35.784759 -78.621088    4
# 5   35.978940 -78.514673    5
# 6   35.650989 -78.704009    6
# 7   35.789286 -78.637452    7
# 8   35.866849 -78.541749    8
# 9   35.705889 -78.795741    9
# 10  35.784899 -78.584733   10
# 11  35.853226 -78.840990   11
# 12  35.734802 -78.647729   12
# 13  35.752833 -78.643243   13
# 14  35.780132 -78.642965   15
# 15  35.823963 -78.613358   16
# 16  35.828716 -78.307180   17

# %%
#merge the df's together, df on index, lat_lng_df on IND, and only merge those that match on lat_lng_df
new_df = pd.merge(df1, lat_lng_df, left_on=df.index, right_on=lat_lng_df.IND, how='inner')

# %%
new_df = new_df.rename(columns={"COLLEGENAME": "collegename", "ADDRESS": "address", "CITY": "city", "State": "state", "LAT": "lat", "LNG": "lng"})
new_df = new_df[["collegename", "address", "city", "state", "lat", "lng"]]
new_df
# Out:
#                                           collegename  \
# 0                   NC State University - Main Campus
# 1                                    Meredith College
# 2                              NCSU Centennial Campus
# 3                                     Shaw University
# 4                               St. Augustine College
# 5                       Southeastern Baptist Seminary
# 6         Wake Technical College Southern Wake Campus
# 7                            William Peace University
# 8         Wake Technical College Northern Wake Campus
# 9          Wake Technical College Western Wake Campus
# 10  Wake Technical College Perry Health Sciences C...
# 11                  Wake Technical College RTP Campus
# 12  Wake Technical College Public Safety Education...
# 13           Vernon Malone College and Career Academy
# 14                     Campbell University Law School
# 15   Wake Technical College Beltline Education Center
# 16  Wake Technical College Eastern Wake Education ...
#
#                          address         city state        lat        lng
# 0       2101 Hillsborough Street      Raleigh    NC  35.786397 -78.663136
# 1       3800 Hillsborough Street      Raleigh    NC  35.794490 -78.687897
# 2           1007 Capability Road      Raleigh    NC  35.770636 -78.681508
# 3               118 South Street      Raleigh    NC  35.772376 -78.642150
# 4            1315 Oakwood Avenue      Raleigh    NC  35.784759 -78.621088
# 5          219 S. Wingate Street  Wake Forest    NC  35.978940 -78.514673
# 6         9101 Fayetteville Road  Wake County    NC  35.650989 -78.704009
# 7             15 E. Peace Street      Raleigh    NC  35.789286 -78.637452
# 8             6600 Louisburg Rd       Raleigh    NC  35.866849 -78.541749
# 9          3434 Kildaire Farm Rd         Cary    NC  35.705889 -78.795741
# 10               2901 Holston Ln      Raleigh    NC  35.784899 -78.584733
# 11          10908 Chapel Hill Rd  Morrisville    NC  35.853226 -78.840990
# 12              321 Chapanoke Rd      Raleigh    NC  35.734802 -78.647729
# 13  2200 South Wilmington Street      Raleigh    NC  35.752833 -78.643243
# 14           225 Hillsborough St      Raleigh    NC  35.780132 -78.642965
# 15                  3200 Bush St      Raleigh    NC  35.823963 -78.613358
# 16           519 N Industrial Dr      Zebulon    NC  35.828716 -78.307180

# %%
import sqlite3
import psycopg2
from sqlalchemy import create_engine

engine = create_engine("postgres://onmtvcaenewtsa:3e19a8202f1bb4493b27c235aa13f7cf9131c76aef0ccdcca291457518007864@ec2-174-129-226-232.compute-1.amazonaws.com:5432/dfl7he1lroc56p")
new_df.to_sql('colleges', engine, index=True, if_exists='replace')

# %%
#pandas – csv in raw folder
new_df.to_csv('raw/cleaned_colleges.csv', index=False, header=None)

# %%
pd.read_sql_query('select * from colleges', con=engine).head()
# Out:
#    index                        collegename                   address  \
# 0      0  NC State University - Main Campus  2101 Hillsborough Street
# 1      1                   Meredith College  3800 Hillsborough Street
# 2      2             NCSU Centennial Campus      1007 Capability Road
# 3      3                    Shaw University          118 South Street
# 4      4              St. Augustine College       1315 Oakwood Avenue
#
#       city state        lat        lng
# 0  Raleigh    NC  35.786397 -78.663136
# 1  Raleigh    NC  35.794490 -78.687897
# 2  Raleigh    NC  35.770636 -78.681508
# 3  Raleigh    NC  35.772376 -78.642150
# 4  Raleigh    NC  35.784759 -78.621088
