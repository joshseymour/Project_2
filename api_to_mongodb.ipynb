# %%
import pandas as pd
import numpy as np

# %%
#import csv

df = pd.read_csv("raw/Colleges_and_Universities.csv")
df
#data cleaning with street matching api format needed pull lat long 
#drog unnecessary address
# Out:
#                X              Y  OBJECTID                       ADDRESS  \
# 0   2.097579e+06  741713.299902         1      2101 Hillsborough Street
# 1   2.092281e+06  744629.599844         2      3800 Hillsborough Street
# 2   2.095116e+06  736981.100049         3          1007 Capability Road
# 3   2.107643e+06  735692.700066         4              118 South Street
# 4   2.112693e+06  741014.500118         5           1315 Oakwood Avenue
# 5   2.144425e+06  812169.599934         6         219 S. Wingate Street
# 6   2.087623e+06  692108.900095         7        9101 Fayetteville Road
# 7   2.107440e+06  742210.100089         8            15 E. Peace Street
# 8   2.134938e+06  770863.000133         9            6600 Louisburg Rd
# 9   2.060739e+06  711927.599959        10         3434 Kildaire Farm Rd
# 10  2.122848e+06  740698.100161        11               2901 Holston Ln
# 11  2.049020e+06  766080.999854        12          10908 Chapel Hill Rd
# ...

# %%
df["State"] = np.nan

# %%
df
# Out:
#                X              Y  OBJECTID                       ADDRESS  \
# 0   2.097579e+06  741713.299902         1      2101 Hillsborough Street
# 1   2.092281e+06  744629.599844         2      3800 Hillsborough Street
# 2   2.095116e+06  736981.100049         3          1007 Capability Road
# 3   2.107643e+06  735692.700066         4              118 South Street
# 4   2.112693e+06  741014.500118         5           1315 Oakwood Avenue
# 5   2.144425e+06  812169.599934         6         219 S. Wingate Street
# 6   2.087623e+06  692108.900095         7        9101 Fayetteville Road
# 7   2.107440e+06  742210.100089         8            15 E. Peace Street
# 8   2.134938e+06  770863.000133         9            6600 Louisburg Rd
# 9   2.060739e+06  711927.599959        10         3434 Kildaire Farm Rd
# 10  2.122848e+06  740698.100161        11               2901 Holston Ln
# 11  2.049020e+06  766080.999854        12          10908 Chapel Hill Rd
# ...

# %%
df = df.fillna('NC')

# %%
df
# Out:
#                X              Y  OBJECTID                       ADDRESS  \
# 0   2.097579e+06  741713.299902         1      2101 Hillsborough Street
# 1   2.092281e+06  744629.599844         2      3800 Hillsborough Street
# 2   2.095116e+06  736981.100049         3          1007 Capability Road
# 3   2.107643e+06  735692.700066         4              118 South Street
# 4   2.112693e+06  741014.500118         5           1315 Oakwood Avenue
# 5   2.144425e+06  812169.599934         6         219 S. Wingate Street
# 6   2.087623e+06  692108.900095         7        9101 Fayetteville Road
# 7   2.107440e+06  742210.100089         8            15 E. Peace Street
# 8   2.134938e+06  770863.000133         9            6600 Louisburg Rd
# 9   2.060739e+06  711927.599959        10         3434 Kildaire Farm Rd
# 10  2.122848e+06  740698.100161        11               2901 Holston Ln
# 11  2.049020e+06  766080.999854        12          10908 Chapel Hill Rd
# ...

# %%
cols = df.columns.tolist()

# %%
cols
# Out:
# ['X', 'Y', 'OBJECTID', 'ADDRESS', 'CITY', 'COLLEGENAME', 'State']

# %%
df = df[['COLLEGENAME','ADDRESS', 'CITY','State']]

# %%
df
# Out:
#                                           COLLEGENAME  \
# 0                   NC State University - Main Campus
# 1                                    Meredith College
# 2                              NCSU Centennial Campus
# 3                                     Shaw University
# 4                               St. Augustine College
# 5                       Southeastern Baptist Seminary
# 6         Wake Technical College Southern Wake Campus
# 7                            William Peace University
# 8         Wake Technical College Northern Wake Campus
# 9          Wake Technical College Western Wake Campus
# 10  Wake Technical College Perry Health Sciences C...
# 11                  Wake Technical College RTP Campus
# 12  Wake Technical College Public Safety Education...
# 13           Vernon Malone College and Career Academy
# 14                           Campbell University ext.
# 15                     Campbell University Law School
# ...

# %%
df
df['location'] = df[["ADDRESS", "CITY", "State"]].apply(lambda x: ' '.join(x), axis=1)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df1 = df.drop(columns=["ADDRESS", "CITY", "State"])

# %%
df[]
# Out:
#   File "<ipython-input-13-71f11347ebfc>", line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
import googlemaps

# %%
loc_coordinates = []
loc_address = []
for location in df:
    try:

        location = g.geocode(inputAddress, timeout=15)
        loc_coordinates.append((location.latitude, location.longitude))
        loc_address.append(inputAddress)
    except Exception as e:
        print('Error, skipping address...', e)


df_geocodes = pd.DataFrame({'coordinate':loc_coordinates,'address':loc_address})
# Out:
# Error, skipping address... name 'g' is not defined
# Error, skipping address... name 'g' is not defined
# Error, skipping address... name 'g' is not defined
# Error, skipping address... name 'g' is not defined
# Error, skipping address... name 'g' is not defined

# %%
df1["Lat"] = None 
df1["Long"] = None 


gmaps_key = googlemaps.Client(key = "AIzaSyBiBAswT9_Is4Lf3gvrcsjLimgNjApWj3Q")

for i in range(0, len(df1), 1):
    geocode_result = gmaps_key.geocode(df1.iat[i, 0])
    try: 
        lat = geocode_result["geometry"]["location"]["lat"]
        long = geocode_result["geometry"]["location"]["lng"]
        df1.iat[i, df1.columns.get_loc("Lat")] = lat
        df1.iat[i, df1.columns.get_loc("Long")] = long
        
    except:
        lat = None
        long = None

# %%
df1
# Out:
#                                           COLLEGENAME  \
# 0                   NC State University - Main Campus
# 1                                    Meredith College
# 2                              NCSU Centennial Campus
# 3                                     Shaw University
# 4                               St. Augustine College
# 5                       Southeastern Baptist Seminary
# 6         Wake Technical College Southern Wake Campus
# 7                            William Peace University
# 8         Wake Technical College Northern Wake Campus
# 9          Wake Technical College Western Wake Campus
# 10  Wake Technical College Perry Health Sciences C...
# 11                  Wake Technical College RTP Campus
# 12  Wake Technical College Public Safety Education...
# 13           Vernon Malone College and Career Academy
# 14                           Campbell University ext.
# 15                     Campbell University Law School
# ...
